# %% [markdown]
# # Fifa19 Exercise - Solutions
#
# Welcome to a quick exercise for you to practice your pandas skills! We will be using the [Fifa19 Dataset](https://www.kaggle.com/winterbreeze/fifa19eda) from Kaggle! Just follow along and complete the tasks outlined in bold below. The tasks will get harder and harder as you go along.

# %% [markdown]
# #### Read fifa_eda.csv

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/Users/immortal/Desktop/DataScience/DataScienceCourse/Analysis/data/fifa_eda.csv')
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# ...                    ...       ...     ...             ...
# 18202           2019-01-01  5.750000   134.0           143.0
# 18203           2020-01-01  6.250000   170.0           113.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [18207 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        18207 non-null  int64
#  1   Name                      18207 non-null  object
#  2   Age                       18207 non-null  int64
#  3   Nationality               18207 non-null  object
#  4   Overall                   18207 non-null  int64
#  5   Potential                 18207 non-null  int64
#  6   Club                      17966 non-null  object
#  7   Value                     17955 non-null  float64
#  8   Wage                      18207 non-null  float64
#  9   Preferred Foot            18207 non-null  object
#  10  International Reputation  18159 non-null  float64
#  11  Skill Moves               18159 non-null  float64
#  12  Position                  18207 non-null  object
#  13  Joined                    18207 non-null  int64
#  14  Contract Valid Until      17918 non-null  object
#  15  Height                    18207 non-null  float64
#  16  Weight                    18207 non-null  float64
#  17  Release Clause            18207 non-null  float64
# dtypes: float64(7), int64(5), object(6)
# memory usage: 2.5+ MB

# %% [markdown]
# ### New Part Visualiztion Questions

# %% [markdown]
# #### Draw the outliers of players value

# %%
sns.set(rc={'figure.figsize':(25,5)})

sns.boxenplot(df['Value']) # It seems like the outliers between 90000 to 120000
# Out:
# /Users/immortal/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Value'>

# %% [markdown]
# #### find the average wage for each Nationality and draw the outliers in value for the top 5 nationality

# %%
df.groupby(['Nationality'])['Wage'].mean().sort_values(ascending=False).head() # The top average wage Nationality
# Out:
# Nationality
# Dominican Republic      71.000000
# United Arab Emirates    39.000000
# Gabon                   26.933333
# Armenia                 22.000000
# Croatia                 21.682540
# Name: Wage, dtype: float64

# %%
df[(df['Nationality']=='Dominican Republic')|(df['Nationality']=='United Arab Emirates')|(df['Nationality']=='Gabon')|(df['Nationality']=='Armenia')|(df['Nationality']=='Croatia')] # data frame for the top 5
# Out:
#            ID           Name  Age Nationality  Overall  Potential  \
# 6      177003      L. Modrić   32     Croatia       91         91
# 33     188567  P. Aubameyang   29       Gabon       88         88
# 53     168651     I. Rakitić   30     Croatia       87         87
# 97     181458     I. Perišić   29     Croatia       85         85
# 139    181783   M. Mandžukić   32     Croatia       84         84
# ...       ...            ...  ...         ...      ...        ...
# 16588  244683   K. Kovačević   23     Croatia       57         61
# 16830  236413   S. Kulenović   18     Croatia       56         75
# 17741  245002       P. Durin   17     Croatia       52         74
# 17927  243796      D. Hodzic   22     Croatia       51         61
# 18034  244794       M. Alvir   24     Croatia       50         55
#
#                   Club    Value   Wage Preferred Foot  \
# 6          Real Madrid  67000.0  420.0          Right
# 33             Arsenal  59000.0  265.0          Right
# 53        FC Barcelona  46500.0  260.0          Right
# 97               Inter  37500.0  110.0          Right
# 139           Juventus  25000.0  160.0          Right
# ...                ...      ...    ...            ...
# 16588     TSV Hartberg    140.0    1.0          Right
# 16830   Legia Warszawa    190.0    1.0          Right
# 17741       Portsmouth     90.0    1.0          Right
# 17927   Vejle Boldklub     50.0    1.0          Right
# 18034  SK Slavia Praha     40.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 6                           4.0          4.0      RCM    2012
# 33                          3.0          4.0       LM    2018
# 53                          4.0          3.0      RCM    2014
# 97                          3.0          4.0       LM    2015
# 139                         3.0          3.0       ST    2015
# ...                         ...          ...      ...     ...
# 16588                       1.0          2.0       ST    2018
# 16830                       1.0          2.0       ST    2016
# 17741                       1.0          1.0       GK    2018
# 17927                       1.0          1.0       GK    2017
# 18034                       1.0          2.0       CM    2017
#
#       Contract Valid Until    Height  Weight  Release Clause
# 6               2020-01-01  5.666667   146.0        137400.0
# 33              2021-01-01  6.166667   176.0        112100.0
# 53              2021-01-01  6.000000   172.0         95300.0
# 97              2022-01-01  6.083333   176.0         63800.0
# 139             2020-01-01  6.250000   187.0         41300.0
# ...                    ...       ...     ...             ...
# 16588           2021-01-01  6.166667   176.0           214.0
# 16830           2023-01-01  6.166667   168.0           385.0
# 17741           2020-01-01  6.083333   176.0           248.0
# 17927           2018-01-01  6.750000   176.0            73.0
# 18034           2019-01-01  5.916667   172.0            91.0
#
# [154 rows x 18 columns]

# %%
sns.set(rc={'figure.figsize':(10,5)})
sns.boxplot(data=df[(df['Nationality']=='Dominican Republic')|(df['Nationality']=='United Arab Emirates')|(df['Nationality']=='Gabon')|(df['Nationality']=='Armenia')|(df['Nationality']=='Croatia')],x='Nationality',y='Wage')
# Out:
# <AxesSubplot:xlabel='Nationality', ylabel='Wage'>

# %% [markdown]
# #### Draw the distripution of players Height

# %%
sns.displot(df['Height'],kind="kde")

# %% [markdown]
# #### What are the top 10 clubs in the wage and visualize the results ?

# %%
df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False).iloc[0:10]
# Out:
# Club
# Real Madrid          5017.0
# FC Barcelona         4837.0
# Manchester City      3741.0
# Manchester United    3391.0
# Juventus             3292.0
# Chelsea              3249.0
# Liverpool            2902.0
# Tottenham Hotspur    2623.0
# Arsenal              2588.0
# FC Bayern München    2286.0
# Name: Wage, dtype: float64

# %%
df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False).iloc[0:10].index
# Out:
# Index(['Real Madrid', 'FC Barcelona', 'Manchester City', 'Manchester United',
#        'Juventus', 'Chelsea', 'Liverpool', 'Tottenham Hotspur', 'Arsenal',
#        'FC Bayern München'],
#       dtype='object', name='Club')

# %%
top_df=df[(df['Club']=='Real Madrid')|(df['Club']=='FC Barcelona')|(df['Club']=='Manchester City')|(df['Club']=='Manchester United')|(df['Club']=='Juventus')
  |(df['Club']=='Chelsea')|(df['Club']=='Liverpool')|(df['Club']=='Tottenham Hotspur')|(df['Club']=='Arsenal')|(df['Club']=='FC Bayern München') ]

top_df
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 0      158023           L. Messi   31   Argentina       94         94
# 1       20801  Cristiano Ronaldo   33    Portugal       94         94
# 3      193080             De Gea   27       Spain       91         93
# 4      192985       K. De Bruyne   27     Belgium       91         92
# 5      183277          E. Hazard   27     Belgium       91         91
# ...       ...                ...  ...         ...      ...        ...
# 16216  233442       J. Osei-Tutu   19     England       58         74
# 16403  233048    T. Dele-Bashiru   18     England       57         76
# 16806  238186           M. Bulka   18      Poland       56         74
# 16932  241859        R. Hoffmann   19     Germany       56         74
# 17451  224947        D. Grimshaw   20     England       54         68
#
#                     Club     Value   Wage Preferred Foot  \
# 0           FC Barcelona  110500.0  565.0           Left
# 1               Juventus   77000.0  405.0          Right
# 3      Manchester United   72000.0  260.0          Right
# 4        Manchester City  102000.0  355.0          Right
# 5                Chelsea   93000.0  340.0          Right
# ...                  ...       ...    ...            ...
# 16216            Arsenal     240.0    4.0          Right
# 16403    Manchester City     210.0    6.0          Right
# 16806            Chelsea     150.0    2.0          Right
# 16932  FC Bayern München     160.0    2.0          Right
# 17451    Manchester City     120.0    6.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# 5                           4.0          4.0       LF    2012
# ...                         ...          ...      ...     ...
# 16216                       1.0          2.0       RB    2015
# 16403                       1.0          2.0       CM    2017
# 16806                       1.0          1.0       GK    2016
# 16932                       1.0          1.0       GK    2017
# 17451                       1.0          1.0       GK    2016
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# 5               2020-01-01  5.666667   163.0        172100.0
# ...                    ...       ...     ...             ...
# 16216           2021-01-01  5.833333   159.0           606.0
# 16403           2019-01-01  5.833333   150.0           520.0
# 16806           2019-01-01  6.500000   198.0           371.0
# 16932           2021-01-01  6.333333   185.0           364.0
# 17451           2021-01-01  6.083333   170.0           297.0
#
# [318 rows x 18 columns]

# %%
sns.barplot(x='Club' , y='Wage' , data=top_df , estimator=sum )
# Out:
# <AxesSubplot:xlabel='Club', ylabel='Wage'>

# %% [markdown]
# #### is there any outlier in the Age find it with 1- visualization 2-  with pandas ?

# %%
sns.boxenplot(df['Age']) # from the graph the outlier begins from 40 to 45
# Out:
# /Users/immortal/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
IQR=df['Age'].quantile(0.75)-df['Age'].quantile(0.25)
IQR
# Out:
# 7.0

# %%
upper_limit=df['Age'].quantile(0.75)+(1.5*IQR)
lower_limit=df['Age'].quantile(0.25)-(1.5*IQR)
upper_limit,lower_limit
# Out:
# (38.5, 10.5)

# %%
df_clean=df[(df['Age']<=upper_limit)|(df['Age']<=lower_limit)] # New data frame with remove all the outliers
df_clean
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# ...                    ...       ...     ...             ...
# 18202           2019-01-01  5.750000   134.0           143.0
# 18203           2020-01-01  6.250000   170.0           113.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [18160 rows x 18 columns]

# %%
sns.boxenplot(df_clean['Age']) #New grapgh without outliers
# Out:
# /Users/immortal/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# #### Is there a correlation between Value and Overall and viusalize the results with two graphs?**

# %%
df[['Wage','Value' ,'Overall','Height']].corr() # There is a correlation between wage and value and overall
# Out:
#              Wage     Value   Overall    Height
# Wage     1.000000  0.858086  0.571926  0.019638
# Value    0.858086  1.000000  0.631848  0.002827
# Overall  0.571926  0.631848  1.000000  0.038527
# Height   0.019638  0.002827  0.038527  1.000000

# %%
sns.barplot(x='Overall' , y='Value', data=df)
# Out:
# <AxesSubplot:xlabel='Overall', ylabel='Value'>

# %% [markdown]
# #### what are the ratio of the Preferred Foot and visualize with a graph ?

# %%
df['Preferred Foot'].value_counts()
# Out:
# Right    13996
# Left      4211
# Name: Preferred Foot, dtype: int64

# %%
sns.displot(x='Preferred Foot', data=df)

# %% [markdown]
# #### what are the top 10 average overall clubs and visualize with a graph ?

# %%
df.groupby('Club')['Overall'].mean().sort_values(ascending=False).iloc[0:10]
# Out:
# Club
# Juventus               82.280000
# Napoli                 80.000000
# Inter                  79.750000
# Real Madrid            78.242424
# Milan                  78.074074
# FC Barcelona           78.030303
# Paris Saint-Germain    77.433333
# Roma                   77.423077
# Manchester United      77.242424
# FC Bayern München      77.000000
# Name: Overall, dtype: float64

# %%
top2_df=df[(df['Club']=='Juventus')|(df['Club']=='Napoli')|(df['Club']=='Inter')|(df['Club']=='Real Madrid')|(df['Club']=='Milan')
  |(df['Club']=='FC Barcelona')|(df['Club']=='Paris Saint-Germain')|(df['Club']=='Roma')|(df['Club']=='Manchester United')|(df['Club']=='FC Bayern München') ]
top2_df # The new data frame for top overall clubs
# Out:
#            ID               Name  Age Nationality  Overall  Potential  \
# 0      158023           L. Messi   31   Argentina       94         94
# 1       20801  Cristiano Ronaldo   33    Portugal       94         94
# 2      190871          Neymar Jr   26      Brazil       92         93
# 3      193080             De Gea   27       Spain       91         93
# 6      177003          L. Modrić   32     Croatia       91         91
# ...       ...                ...  ...         ...      ...        ...
# 14244  245100         M. Awoudja   20     Germany       61         72
# 14253  246127            P. Will   19     Germany       61         77
# 14286  246139         Iñaki Peña   19       Spain       61         78
# 15430  243514           J. Meier   18     Germany       59         75
# 16932  241859        R. Hoffmann   19     Germany       56         74
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 6              Real Madrid   67000.0  420.0          Right
# ...                    ...       ...    ...            ...
# 14244    FC Bayern München     375.0    6.0          Right
# 14253    FC Bayern München     525.0    5.0           Left
# 14286         FC Barcelona     450.0    4.0          Right
# 15430    FC Bayern München     290.0    3.0           Left
# 16932    FC Bayern München     160.0    2.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 6                           4.0          4.0      RCM    2012
# ...                         ...          ...      ...     ...
# 14244                       1.0          2.0       CB    2018
# 14253                       1.0          3.0       CM    2018
# 14286                       1.0          1.0       GK    2018
# 15430                       1.0          2.0       LB    2018
# 16932                       1.0          1.0       GK    2017
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 6               2020-01-01  5.666667   146.0        137400.0
# ...                    ...       ...     ...             ...
# 14244           2021-01-01  6.166667   190.0           694.0
# 14253           2021-01-01  6.083333   170.0          1200.0
# 14286           2021-01-01  6.000000   172.0          1200.0
# 15430           2021-01-01  5.833333   172.0           660.0
# 16932           2021-01-01  6.333333   185.0           364.0
#
# [285 rows x 18 columns]

# %%
sns.barplot(x='Club', y='Overall' , data=top2_df)
# Out:
# <AxesSubplot:xlabel='Club', ylabel='Overall'>

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# 0             FC Barcelona  110500.0  565.0           Left
# 1                 Juventus   77000.0  405.0          Right
# 2      Paris Saint-Germain  118500.0  290.0          Right
# 3        Manchester United   72000.0  260.0          Right
# 4          Manchester City  102000.0  355.0          Right
# ...                    ...       ...    ...            ...
# 18202      Crewe Alexandra      60.0    1.0          Right
# 18203       Trelleborgs FF      60.0    1.0          Right
# 18204     Cambridge United      60.0    1.0          Right
# 18205      Tranmere Rovers      60.0    1.0          Right
# 18206      Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 1                           5.0          5.0       ST    2018
# 2                           5.0          5.0       LW    2017
# 3                           4.0          1.0       GK    2011
# 4                           4.0          4.0      RCM    2015
# ...                         ...          ...      ...     ...
# 18202                       1.0          2.0       CM    2017
# 18203                       1.0          2.0       ST    2018
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 1               2022-01-01  6.166667   183.0        127100.0
# 2               2022-01-01  5.750000   150.0        228100.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 4               2023-01-01  5.916667   154.0        196400.0
# ...                    ...       ...     ...             ...
# 18202           2019-01-01  5.750000   134.0           143.0
# 18203           2020-01-01  6.250000   170.0           113.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [18207 rows x 18 columns]

# %% [markdown]
# **What are the top 5 most common nationality and visualize them with a graph?**

# %%
df['Nationality'].value_counts().head()
# Out:
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: Nationality, dtype: int64

# %%
new_df3=df[(df['Nationality']=='England')|(df['Nationality']=='Germany')|(df['Nationality']=='Spain')|(df['Nationality']=='Argentina')|(df['Nationality']=='France')]
new_df3 #New data frame for the 5 most common nationality
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 0      158023        L. Messi   31   Argentina       94         94
# 3      193080          De Gea   27       Spain       91         93
# 8      155862    Sergio Ramos   32       Spain       91         91
# 11     182521        T. Kroos   28     Germany       90         90
# 13     168542     David Silva   32       Spain       90         90
# ...       ...             ...  ...         ...      ...        ...
# 18198  242844      J. Livesey   18     England       47         70
# 18202  238813    J. Lundstram   19     England       47         65
# 18204  241638       B. Worman   16     England       47         67
# 18205  246268  D. Walker-Rice   17     England       47         66
# 18206  246269       G. Nugent   16     England       46         66
#
#                     Club     Value   Wage Preferred Foot  \
# 0           FC Barcelona  110500.0  565.0           Left
# 3      Manchester United   72000.0  260.0          Right
# 8            Real Madrid   51000.0  380.0          Right
# 11           Real Madrid   76500.0  355.0          Right
# 13       Manchester City   60000.0  285.0           Left
# ...                  ...       ...    ...            ...
# 18198      Burton Albion      60.0    1.0          Right
# 18202    Crewe Alexandra      60.0    1.0          Right
# 18204   Cambridge United      60.0    1.0          Right
# 18205    Tranmere Rovers      60.0    1.0          Right
# 18206    Tranmere Rovers      60.0    1.0          Right
#
#        International Reputation  Skill Moves Position  Joined  \
# 0                           5.0          4.0       RF    2004
# 3                           4.0          1.0       GK    2011
# 8                           4.0          3.0      RCB    2005
# 11                          4.0          3.0      LCM    2014
# 13                          4.0          4.0      LCM    2010
# ...                         ...          ...      ...     ...
# 18198                       1.0          1.0       GK    2018
# 18202                       1.0          2.0       CM    2017
# 18204                       1.0          2.0       ST    2017
# 18205                       1.0          2.0       RW    2018
# 18206                       1.0          2.0       CM    2018
#
#       Contract Valid Until    Height  Weight  Release Clause
# 0               2021-01-01  5.583333   159.0        226500.0
# 3               2020-01-01  6.333333   168.0        138600.0
# 8               2020-01-01  6.000000   181.0        104600.0
# 11              2022-01-01  6.000000   168.0        156800.0
# 13              2020-01-01  5.666667   148.0        111000.0
# ...                    ...       ...     ...             ...
# 18198           2021-01-01  5.916667   154.0           165.0
# 18202           2019-01-01  5.750000   134.0           143.0
# 18204           2021-01-01  5.666667   148.0           165.0
# 18205           2019-01-01  5.833333   154.0           143.0
# 18206           2019-01-01  5.833333   176.0           165.0
#
# [5783 rows x 18 columns]

# %%
sns.displot(x='Nationality', data=new_df3)

# %% [markdown]
# # Great Job!
